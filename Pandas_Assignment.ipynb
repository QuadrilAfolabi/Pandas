# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Assignment 1
#
# 1. Collate the following informations for every 36 states in Nigeria.
#
#     1. State Name
#     2. State Capital
#     3. State Population
#     4. State Landmass
#
# 2. Create a Pandas Series object of state population and landmass using state name as the key of both.
# 3. From the two Series objects, create a DataFrame object and add the state capital as new collumn to the table.
# 4. Calculate the population density of each state and use it to generate a new collumn on the DataFrame object.

# %%
state=pd.Series(['Abia State','Adamawa','Akwa Ibom','Anambra','Bauchi','Bayelsa','Benue','Borno','Cross River','Delta','Ebonyi','Edo','Ekiti','Enugu','Gombe','Imo','Jigawa','Kaduna','Kano','Katsina','Kebbi', 'Kogi','Kwara','Lagos','Nasarawa','Niger','Ogun','Ondo','Osun','Oyo','Plateau','Rivers','Sokoto','Taraba','Yobe','Zamfara','Federal Capital Territory'])
# state

capital=pd.Series(['Umuahia','Yola', 'Uyo','Akwa','Bauchi','Yenagoa', "Makurdi", 'Maiduguri', 'Calabar', 'Asaba', 'Abakaliki', 'Benin City', 'Ado Ekiti', 'Enugu','Gombe','Owerri', 'Dutse', 'Kaduna', 'Kano', 'Katsina', 'Birnin Kebbi', 'Lokoja', 'Ilorin', 'Ikeja', 'Lafia', 'Minna', 'Abeokuta', 'Akure', 'Oshogbo', 'Ibadan', 'Jos', 'Port Harcourt', 'Sokoto', 'Jalingo', 'Damaturu', 'Gusau', 'Abuja' ])
# capital

population =pd.Series([3841943, 4536948, 4780581, 5599910, 7540663, 2394725, 5787706, 5751590, 4175020, 5307543, 3007155, 4461137, 3350401, 4396098, 3623462, 5167722, 6779080, 8324285, 14253549, 9300382,5001610, 4153734, 3259613, 12772884, 2632239, 6220617, 5945275, 4969707, 4237396, 7512855, 4400974, 7034973, 5863187, 3331885, 3398177, 5317793, 2702443 ])
# population

landmass =pd.Series([6320, 36917,7081,4844,45893, 10773,34059, 70898,20156, 17698, 5670, 17802, 6353, 7161, 18768, 5530, 23154, 46053, 20131, 24192, 36800, 29833, 36825, 3345, 27117, 76363, 16762, 15500, 9251, 28454, 30913, 11077, 25973, 54473, 45502, 39762, 7315])
# landmass

# %%
census =pd.DataFrame({'State':state, 'Capital':capital, 'Population':population, 'Landmass(kmsq)':landmass})
# census 
census['Density']=census.Population / census['Landmass(kmsq)']

# %% [markdown]
# ## The following table pressents a listing of Nigeria 36 states with their 2019 projected populations and their land mass which were publish by National Bureau of Statistics.

# %%
census
# Out:
#                         State        Capital  Population  Landmass(kmsq)  \
# 0                  Abia State        Umuahia     3841943            6320
# 1                     Adamawa           Yola     4536948           36917
# 2                   Akwa Ibom            Uyo     4780581            7081
# 3                     Anambra           Akwa     5599910            4844
# 4                      Bauchi         Bauchi     7540663           45893
# 5                     Bayelsa        Yenagoa     2394725           10773
# 6                       Benue        Makurdi     5787706           34059
# 7                       Borno      Maiduguri     5751590           70898
# 8                 Cross River        Calabar     4175020           20156
# 9                       Delta          Asaba     5307543           17698
# 10                     Ebonyi      Abakaliki     3007155            5670
# 11                        Edo     Benin City     4461137           17802
# ...

# %%
census['S/N'] = np.arange(1,census['State'].count()+1)
census
# Out:
#                         State        Capital  Population  Landmass(kmsq)  \
# 0                  Abia State        Umuahia     3841943            6320
# 1                     Adamawa           Yola     4536948           36917
# 2                   Akwa Ibom            Uyo     4780581            7081
# 3                     Anambra           Akwa     5599910            4844
# 4                      Bauchi         Bauchi     7540663           45893
# 5                     Bayelsa        Yenagoa     2394725           10773
# 6                       Benue        Makurdi     5787706           34059
# 7                       Borno      Maiduguri     5751590           70898
# 8                 Cross River        Calabar     4175020           20156
# 9                       Delta          Asaba     5307543           17698
# 10                     Ebonyi      Abakaliki     3007155            5670
# 11                        Edo     Benin City     4461137           17802
# ...

# %%
census = census.reindex(census['S/N']).drop(['S/N'], axis = 1)
census
# Out:
#                          State        Capital  Population  Landmass(kmsq)  \
# S/N
# 1                      Adamawa           Yola   4536948.0         36917.0
# 2                    Akwa Ibom            Uyo   4780581.0          7081.0
# 3                      Anambra           Akwa   5599910.0          4844.0
# 4                       Bauchi         Bauchi   7540663.0         45893.0
# 5                      Bayelsa        Yenagoa   2394725.0         10773.0
# 6                        Benue        Makurdi   5787706.0         34059.0
# 7                        Borno      Maiduguri   5751590.0         70898.0
# 8                  Cross River        Calabar   4175020.0         20156.0
# 9                        Delta          Asaba   5307543.0         17698.0
# 10                      Ebonyi      Abakaliki   3007155.0          5670.0
# 11                         Edo     Benin City   4461137.0         17802.0
# 12                       Ekiti      Ado Ekiti   3350401.0          6353.0
# ...

# %%
# Assignment 2 

# extract all the values that is not null from the dataset to a new variable
# extract all the null value from the dataset into a new variable
# drop all columns where all value is null from the original dataset
# clean the dataset so it deosn't have any null value again
# compute the sum, mean of the price column on the dataset
# get the car with the lowest price and with the highest price

# %%
data = pd.read_csv('C:\\Users\\Dreamuser\\Desktop\\Pandas Class\\Datasets\\car_scrape4.csv')
data.head()
# Out:
#                    title  odometer location    isimported          engine  \
# 0         Toyota Corolla     60127    Lagos  Locally used  4-cylinder(I4)
# 1              Acura MDX    132908    Lagos  Foreign Used  6-cylinder(V6)
# 2           Lexus ES 350    120412    Lagos  Locally used  6-cylinder(V6)
# 3  Mercedes-Benz GLK 350     67640    Lagos  Foreign Used  4-cylinder(I4)
# 4    Mercedes-Benz E 200     92440    Abuja  Foreign Used  4-cylinder(I4)
#
#   transmission    fuel   paint    price  year
# 0    automatic  petrol  Silver  1995000  2009
# 1    automatic  petrol  Whine   3315000  2009
# 2    automatic  petrol  Silver  2355000  2008
# 3    automatic  petrol   Black  9915000  2013
# 4    automatic  petrol   Black  9790000  2013

# %%
data[data.isnull()].head()
# Out:
#   title  odometer location isimported engine transmission fuel paint  price  \
# 0   NaN       NaN      NaN        NaN    NaN          NaN  NaN   NaN    NaN
# 1   NaN       NaN      NaN        NaN    NaN          NaN  NaN   NaN    NaN
# 2   NaN       NaN      NaN        NaN    NaN          NaN  NaN   NaN    NaN
# 3   NaN       NaN      NaN        NaN    NaN          NaN  NaN   NaN    NaN
# 4   NaN       NaN      NaN        NaN    NaN          NaN  NaN   NaN    NaN
#
#    year
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
data[data.notnull()].head()
# Out:
#                    title  odometer location    isimported          engine  \
# 0         Toyota Corolla     60127    Lagos  Locally used  4-cylinder(I4)
# 1              Acura MDX    132908    Lagos  Foreign Used  6-cylinder(V6)
# 2           Lexus ES 350    120412    Lagos  Locally used  6-cylinder(V6)
# 3  Mercedes-Benz GLK 350     67640    Lagos  Foreign Used  4-cylinder(I4)
# 4    Mercedes-Benz E 200     92440    Abuja  Foreign Used  4-cylinder(I4)
#
#   transmission    fuel   paint    price  year
# 0    automatic  petrol  Silver  1995000  2009
# 1    automatic  petrol  Whine   3315000  2009
# 2    automatic  petrol  Silver  2355000  2008
# 3    automatic  petrol   Black  9915000  2013
# 4    automatic  petrol   Black  9790000  2013

# %%
data.dropna(axis='columns').head()
# Out:
#                    title  odometer location    isimported          engine  \
# 0         Toyota Corolla     60127    Lagos  Locally used  4-cylinder(I4)
# 1              Acura MDX    132908    Lagos  Foreign Used  6-cylinder(V6)
# 2           Lexus ES 350    120412    Lagos  Locally used  6-cylinder(V6)
# 3  Mercedes-Benz GLK 350     67640    Lagos  Foreign Used  4-cylinder(I4)
# 4    Mercedes-Benz E 200     92440    Abuja  Foreign Used  4-cylinder(I4)
#
#   transmission    fuel   paint    price  year
# 0    automatic  petrol  Silver  1995000  2009
# 1    automatic  petrol  Whine   3315000  2009
# 2    automatic  petrol  Silver  2355000  2008
# 3    automatic  petrol   Black  9915000  2013
# 4    automatic  petrol   Black  9790000  2013

# %%
data.dropna()
# Out:
#                       title  odometer location    isimported          engine  \
# 0            Toyota Corolla     60127    Lagos  Locally used  4-cylinder(I4)
# 1                 Acura MDX    132908    Lagos  Foreign Used  6-cylinder(V6)
# 2              Lexus ES 350    120412    Lagos  Locally used  6-cylinder(V6)
# 3     Mercedes-Benz GLK 350     67640    Lagos  Foreign Used  4-cylinder(I4)
# 4       Mercedes-Benz E 200     92440    Abuja  Foreign Used  4-cylinder(I4)
# ...                     ...       ...      ...           ...             ...
# 3171          Ford Explorer    108597    Abuja  Foreign Used  6-cylinder(V6)
# 3172              Ford Edge    145184    Lagos  Foreign Used  6-cylinder(I6)
# 3173           Toyota Camry     88687    Lagos  Foreign Used  4-cylinder(I4)
# 3174      Toyota Highlander     30951    Lagos  Foreign Used  6-cylinder(V6)
# 3175           Toyota Camry     12936    Lagos  Foreign Used  4-cylinder(I4)
#
# ...

# %%
data.dropna(axis='columns', how='all')
# Out:
#                       title  odometer location    isimported          engine  \
# 0            Toyota Corolla     60127    Lagos  Locally used  4-cylinder(I4)
# 1                 Acura MDX    132908    Lagos  Foreign Used  6-cylinder(V6)
# 2              Lexus ES 350    120412    Lagos  Locally used  6-cylinder(V6)
# 3     Mercedes-Benz GLK 350     67640    Lagos  Foreign Used  4-cylinder(I4)
# 4       Mercedes-Benz E 200     92440    Abuja  Foreign Used  4-cylinder(I4)
# ...                     ...       ...      ...           ...             ...
# 3171          Ford Explorer    108597    Abuja  Foreign Used  6-cylinder(V6)
# 3172              Ford Edge    145184    Lagos  Foreign Used  6-cylinder(I6)
# 3173           Toyota Camry     88687    Lagos  Foreign Used  4-cylinder(I4)
# 3174      Toyota Highlander     30951    Lagos  Foreign Used  6-cylinder(V6)
# 3175           Toyota Camry     12936    Lagos  Foreign Used  4-cylinder(I4)
#
# ...

# %%
data['price'].head()
# Out:
# 0    1995000
# 1    3315000
# 2    2355000
# 3    9915000
# 4    9790000
# Name: price, dtype: int64

# %%
data['price'].sum()
# Out:
# 27214291658

# %%
data['price'].max()
# Out:
# 167015008

# %%
data['price'].min()
# Out:
# 215000

# %%
data['title'].max()
# Out:
# 'Volvo XC90'

# %%
data['title'].min()
# Out:
# 'ALPINA B3'
